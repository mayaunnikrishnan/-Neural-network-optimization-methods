# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/customer_purchase_data.csv')

# %%
df.head()
# Out:
#    Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 0   40       1   66120.267939                  8                0
# 1   20       1   23579.773583                  4                2
# 2   27       1  127821.306432                 11                2
# 3   24       1  137798.623120                 19                3
# 4   31       1   99300.964220                 19                1
#
#    TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# 0           30.568601               0                 5               1
# 1           38.240097               0                 5               0
# 2           31.633212               1                 0               1
# 3           46.167059               0                 4               1
# 4           19.823592               0                 0               1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 1500 non-null   int64
#  1   Gender              1500 non-null   int64
#  2   AnnualIncome        1500 non-null   float64
#  3   NumberOfPurchases   1500 non-null   int64
#  4   ProductCategory     1500 non-null   int64
#  5   TimeSpentOnWebsite  1500 non-null   float64
#  6   LoyaltyProgram      1500 non-null   int64
#  7   DiscountsAvailed    1500 non-null   int64
#  8   PurchaseStatus      1500 non-null   int64
# dtypes: float64(2), int64(7)
# memory usage: 105.6 KB

# %%
df['PurchaseStatus'].value_counts()
# Out:
# PurchaseStatus
# 0    852
# 1    648
# Name: count, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Gender
# 1    757
# 0    743
# Name: count, dtype: int64

# %%
print(df['Age'].value_counts())
# Out:
# Age
# 68    43
# 50    42
# 66    40
# 64    40
# 45    38
# 22    37
# 18    34
# 43    34
# 25    34
# 40    33
# 41    33
# 52    33
# 69    33
# 54    33
# 19    32
# 49    31
# 61    30
# 46    30
# 57    30
# 70    30
# 20    30
# 42    29
# 56    29
# 47    29
# 39    29
# 62    28
# 31    27
# 53    27
# 29    27
# 23    27
# 28    27
# 65    26
# 38    26
# 36    26
# 26    26
# 34    25
# 37    25
# 21    25
# 27    24
# 55    24
# 58    23
# 51    23
# 32    23
# 30    23
# 33    22
# 44    22
# 24    22
# 35    21
# 48    20
# 60    20
# 63    19
# 67    19
# 59    17
# Name: count, dtype: int64

# %% [markdown]
# ### Exploratory data analysis

# %%
# Compute the correlation matrix
correlation_matrix = df.corr()

# Plot the heatmap
plt.figure(figsize=(20, 15))
sns.heatmap(correlation_matrix, vmax=0.3, center=0, cmap="PRGn", square=True, linewidths=0.5, cbar_kws={"shrink": 0.5}, annot=True)
plt.tight_layout()
plt.show()

# %%
# Get the Series of correlation values
corr_values = abs(df.corr()['PurchaseStatus']).sort_values()[:-1]
sns.set_style('white')
sns.set_palette('PRGn')
plt.figure(figsize = (13,6))
plt.title('Distribution of correlation of features',fontsize=30,color="blue",pad='2.0',
        loc="left",fontstyle='italic')
# Define the explode values based on the length of the Series
explode = [0.1] * len(corr_values) # Example: setting all explode values to 0.1
textprops = {'color':"blue","fontsize":15}
w={'edgecolor':"black",'linewidth':3,'antialiased':True}
# Plot the pie chart with the correct explode values
corr_values.plot.pie(explode=explode, autopct="%2.1f%%", shadow=True, startangle=90, wedgeprops=w, textprops=textprops, radius=3.0)
plt.axis("off")
plt.legend(bbox_to_anchor=(1.9,0.8),ncol=2,facecolor="yellow",framealpha=0.9,shadow=True,edgecolor="red",fancybox=True)
#plt.tight_layout()
plt.show()

# %%
# Plotting
custom_palette = sns.color_palette("PRGn", 5)
sns.countplot(x='PurchaseStatus', hue='Gender', data=df, palette=custom_palette)
# Set labels and title
plt.xlabel("Purchase Status", size=14)
plt.ylabel("Count", size=14)
plt.title("Purchase Status by Gender", fontsize=14, fontweight="bold")

# Show plot
plt.show()
# Out:
# <ipython-input-85-cb3775754c20>:3: UserWarning: The palette list has more values (5) than needed (2), which may not be intended.
#   sns.countplot(x='PurchaseStatus', hue='Gender', data=df, palette=custom_palette)

# %%
sns.boxplot(x='PurchaseStatus', y='AnnualIncome', data=df,palette=custom_palette)
plt.title("Annual Income by PurchaseStatus")
plt.show()
# Out:
# <ipython-input-86-386c9529706f>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='PurchaseStatus', y='AnnualIncome', data=df,palette=custom_palette)
# <ipython-input-86-386c9529706f>:1: UserWarning: The palette list has more values (5) than needed (2), which may not be intended.
#   sns.boxplot(x='PurchaseStatus', y='AnnualIncome', data=df,palette=custom_palette)

# %%
sns.histplot(df['Age'], kde=True,palette=custom_palette)
plt.title("Age Distribution")
plt.show()
# Out:
# <ipython-input-87-fd2453d93c2a>:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(df['Age'], kde=True,palette=custom_palette)

# %%
sns.boxplot(x='PurchaseStatus', y='Age', data=df,palette=custom_palette)
plt.title("PurchaseStatus by Age")
plt.show()
# Out:
# <ipython-input-88-57a7e2da7355>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='PurchaseStatus', y='Age', data=df,palette=custom_palette)
# <ipython-input-88-57a7e2da7355>:1: UserWarning: The palette list has more values (5) than needed (2), which may not be intended.
#   sns.boxplot(x='PurchaseStatus', y='Age', data=df,palette=custom_palette)

# %%
sns.boxplot(x='PurchaseStatus', y='NumberOfPurchases', data=df,palette=custom_palette,hue='Gender')
plt.title("PurchaseStatus by NumberOfPurchases")
plt.show()
# Out:
# <ipython-input-90-88aa433bd287>:1: UserWarning: The palette list has more values (5) than needed (2), which may not be intended.
#   sns.boxplot(x='PurchaseStatus', y='NumberOfPurchases', data=df,palette=custom_palette,hue='Gender')

# %%
sns.histplot(df['ProductCategory'], kde=True,palette=custom_palette)
plt.title("ProductCategory Distribution")
plt.show()
# Out:
# <ipython-input-93-19e79e9d2549>:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(df['ProductCategory'], kde=True,palette=custom_palette)

# %%
sns.boxplot(x='PurchaseStatus', y='ProductCategory', data=df,palette=custom_palette)
plt.title("PurchaseStatus by ProductCategory")
plt.show()
# Out:
# <ipython-input-94-6b5526d8f46e>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='PurchaseStatus', y='ProductCategory', data=df,palette=custom_palette)
# <ipython-input-94-6b5526d8f46e>:1: UserWarning: The palette list has more values (5) than needed (2), which may not be intended.
#   sns.boxplot(x='PurchaseStatus', y='ProductCategory', data=df,palette=custom_palette)

# %%
sns.violinplot(x='PurchaseStatus', y='TimeSpentOnWebsite', data=df,palette=custom_palette)
plt.title("PurchaseStatus by TimeSpentOnWebsite")
plt.show()
# Out:
# <ipython-input-95-323481b0b11e>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='PurchaseStatus', y='TimeSpentOnWebsite', data=df,palette=custom_palette)
# <ipython-input-95-323481b0b11e>:1: UserWarning: The palette list has more values (5) than needed (2), which may not be intended.
#   sns.violinplot(x='PurchaseStatus', y='TimeSpentOnWebsite', data=df,palette=custom_palette)

# %%
df['LoyaltyProgram'].value_counts()
# Out:
# LoyaltyProgram
# 0    1010
# 1     490
# Name: count, dtype: int64

# %%
sns.countplot(x='PurchaseStatus', hue='LoyaltyProgram', data=df,palette=custom_palette)
plt.title("PurchaseStatus by LoyaltyProgram")
plt.show()
# Out:
# <ipython-input-96-d77f2fddafb8>:1: UserWarning: The palette list has more values (5) than needed (2), which may not be intended.
#   sns.countplot(x='PurchaseStatus', hue='LoyaltyProgram', data=df,palette=custom_palette)

# %%
df['DiscountsAvailed'].value_counts()
# Out:
# DiscountsAvailed
# 3    265
# 5    258
# 4    258
# 1    242
# 0    240
# 2    237
# Name: count, dtype: int64

# %%
sns.countplot(x='PurchaseStatus', hue='DiscountsAvailed', data=df,palette=custom_palette)
plt.title("PurchaseStatus by DiscountsAvailed")
plt.show()
# Out:
# <ipython-input-97-ce1657bd2cae>:1: UserWarning:
# The palette list has fewer values (5) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   sns.countplot(x='PurchaseStatus', hue='DiscountsAvailed', data=df,palette=custom_palette)

# %%
sns.violinplot(x='PurchaseStatus', y='DiscountsAvailed', data=df,palette=custom_palette)
plt.title("PurchaseStatus by DiscountsAvailed")
plt.show()
# Out:
# <ipython-input-98-05987dd13014>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='PurchaseStatus', y='DiscountsAvailed', data=df,palette=custom_palette)
# <ipython-input-98-05987dd13014>:1: UserWarning: The palette list has more values (5) than needed (2), which may not be intended.
#   sns.violinplot(x='PurchaseStatus', y='DiscountsAvailed', data=df,palette=custom_palette)

# %%
df.head()
# Out:
#    Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 0   40       1   66120.267939                  8                0
# 1   20       1   23579.773583                  4                2
# 2   27       1  127821.306432                 11                2
# 3   24       1  137798.623120                 19                3
# 4   31       1   99300.964220                 19                1
#
#    TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# 0           30.568601               0                 5               1
# 1           38.240097               0                 5               0
# 2           31.633212               1                 0               1
# 3           46.167059               0                 4               1
# 4           19.823592               0                 0               1

# %%
X = df.drop(columns=['PurchaseStatus'])
y = df['PurchaseStatus'].values

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

X_train_trf = scaler.fit_transform(X_train)
X_test_trf = scaler.transform(X_test)

# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()

model.add(Dense(8,activation='relu',input_dim=8))
model.add(Dense(8,activation='relu'))
model.add(Dense(8,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_9 (Dense)             (None, 8)                 72
#
#  dense_10 (Dense)            (None, 8)                 72
#
#  dense_11 (Dense)            (None, 8)                 72
#
#  dense_12 (Dense)            (None, 1)                 9
#
# ...
# Total params: 225 (900.00 Byte)
# Trainable params: 225 (900.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.layers[1].get_weights()
# Out:
# [array([[ 0.32780394,  0.11830197,  0.3348915 , -0.29032424,  0.028352  ,
#          -0.39551878, -0.14824285,  0.2423929 ],
#         [ 0.4718651 , -0.4463322 ,  0.39683607, -0.31692556, -0.03202366,
#           0.01846093,  0.1007254 ,  0.2548004 ],
#         [ 0.71434623,  0.0874242 , -0.02606234, -0.01257006,  0.28893515,
#          -0.07217341,  0.13115375,  0.6099644 ],
#         [-0.5559912 ,  0.2656465 , -0.1173953 , -0.27316386, -0.22886337,
#           0.30305108,  0.19521844,  0.70724726],
#         [-0.08272262,  0.6515224 ,  0.18314782, -0.59667224,  0.35549185,
#           0.19179751,  0.47086003, -0.14304917],
#         [-0.07662643, -0.3080381 ,  0.53641117,  0.627238  ,  0.14786944,
#          -0.44132257, -0.77739257,  0.46648738],
#         [ 0.00553175,  0.27199277,  0.10493587,  0.58898765, -0.14952794,
#           0.69286823, -0.00413698, -0.215741  ],
#         [-0.93005556,  0.29451355, -0.57434565, -0.228763  , -0.00736564,
# ...

# %%
model.compile(optimizer='Adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(X_train_trf,y_train,batch_size=50,epochs=100,verbose=1,validation_split=0.2)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 1s 16ms/step - loss: 0.7060 - accuracy: 0.5042 - val_loss: 0.6900 - val_accuracy: 0.5792
# Epoch 2/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.6879 - accuracy: 0.5573 - val_loss: 0.6765 - val_accuracy: 0.6083
# Epoch 3/100
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6744 - accuracy: 0.5823 - val_loss: 0.6646 - val_accuracy: 0.6167
# Epoch 4/100
# 20/20 [==============================] - 0s 8ms/step - loss: 0.6601 - accuracy: 0.6198 - val_loss: 0.6515 - val_accuracy: 0.6583
# Epoch 5/100
# 20/20 [==============================] - 0s 8ms/step - loss: 0.6424 - accuracy: 0.6615 - val_loss: 0.6359 - val_accuracy: 0.6792
# Epoch 6/100
# 20/20 [==============================] - 0s 8ms/step - loss: 0.6222 - accuracy: 0.6969 - val_loss: 0.6178 - val_accuracy: 0.6750
# Epoch 7/100
# ...

# %%
y_pred = model.predict(X_test_trf)
# Out:
# 10/10 [==============================] - 0s 3ms/step

# %%
print(y_pred[0:5])
# Out:
# [[0.22023757]
#  [0.9906003 ]
#  [0.89929026]
#  [0.7803412 ]
#  [0.4503975 ]]

# %%
y_pred=np.where(y_pred>=0.5,1,0)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.8333333333333334

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Graph')
plt.show()

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy Graph')
plt.show()
