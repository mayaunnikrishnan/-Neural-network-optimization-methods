# %%
import numpy as np
import pandas as pd
import time
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/online_course_engagement_data.csv')

# %%
df.head()
# Out:
#    UserID CourseCategory  TimeSpentOnCourse  NumberOfVideosWatched  \
# 0    5618         Health          29.979719                     17
# 1    4326           Arts          27.802640                      1
# 2    5849           Arts          86.820485                     14
# 3    4992        Science          35.038427                     17
# 4    3866    Programming          92.490647                     16
#
#    NumberOfQuizzesTaken  QuizScores  CompletionRate  DeviceType  \
# 0                     3   50.365656       20.860773           1
# 1                     5   62.615970       65.632415           1
# 2                     2   78.458962       63.812007           1
# 3                    10   59.198853       95.433162           0
# 4                     0   98.428285       18.102478           0
#
#    CourseCompletion
# 0                 0
# 1                 0
# 2                 1
# 3                 1
# 4                 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9000 entries, 0 to 8999
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   UserID                 9000 non-null   int64
#  1   CourseCategory         9000 non-null   object
#  2   TimeSpentOnCourse      9000 non-null   float64
#  3   NumberOfVideosWatched  9000 non-null   int64
#  4   NumberOfQuizzesTaken   9000 non-null   int64
#  5   QuizScores             9000 non-null   float64
#  6   CompletionRate         9000 non-null   float64
#  7   DeviceType             9000 non-null   int64
#  8   CourseCompletion       9000 non-null   int64
# dtypes: float64(3), int64(5), object(1)
# memory usage: 632.9+ KB

# %%
df['CourseCategory'].value_counts()
# Out:
# CourseCategory
# Business       1837
# Health         1821
# Science        1814
# Programming    1810
# Arts           1718
# Name: count, dtype: int64

# %%
df['CourseCompletion'].value_counts()
# Out:
# CourseCompletion
# 0    5432
# 1    3568
# Name: count, dtype: int64

# %%
df['DeviceType'].value_counts()
# Out:
# DeviceType
# 1    4506
# 0    4494
# Name: count, dtype: int64

# %%
df['NumberOfQuizzesTaken'].value_counts()
# Out:
# NumberOfQuizzesTaken
# 9     872
# 10    847
# 5     839
# 6     838
# 8     828
# 2     827
# 4     808
# 7     805
# 1     789
# 3     780
# 0     767
# Name: count, dtype: int64

# %%
import seaborn as sns
plt.figure(figsize=(10,5))
sns.histplot(df['NumberOfQuizzesTaken'],kde=True,bins=10,color='pink')
# Out:
# <Axes: xlabel='NumberOfQuizzesTaken', ylabel='Count'>

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=(10,5))
sns.countplot(x='NumberOfQuizzesTaken',data=df,color='pink',hue='CourseCompletion')
# Out:
# <ipython-input-17-f800b08bcf6d>:3: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:pink'` for the same effect.
#
#   sns.countplot(x='NumberOfQuizzesTaken',data=df,color='pink',hue='CourseCompletion')
# <Axes: xlabel='NumberOfQuizzesTaken', ylabel='count'>

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='CourseCategory',y='QuizScores',data=df,hue='CourseCompletion',color='pink')
# Out:
# <ipython-input-20-08772e30e489>:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:pink'` for the same effect.
#
#   sns.barplot(x='CourseCategory',y='QuizScores',data=df,hue='CourseCompletion',color='pink')
# <Axes: xlabel='CourseCategory', ylabel='QuizScores'>

# %%
df['NumberOfVideosWatched'].value_counts()
# Out:
# NumberOfVideosWatched
# 4     463
# 3     463
# 15    459
# 6     454
# 12    449
# 16    437
# 14    433
# 13    432
# 11    432
# 20    431
# 8     429
# 19    427
# 2     422
# 9     421
# 10    419
# 18    415
# 17    408
# 0     408
# 5     406
# 1     401
# 7     391
# Name: count, dtype: int64

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=(10,5))
sns.countplot(x='NumberOfVideosWatched',data=df,color='pink',hue='CourseCompletion')
# Out:
# <ipython-input-14-fea1d0fb7591>:3: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:pink'` for the same effect.
#
#   sns.countplot(x='NumberOfVideosWatched',data=df,color='pink',hue='CourseCompletion')
# <Axes: xlabel='NumberOfVideosWatched', ylabel='count'>

# %%
plt.figure(figsize=(10,5))
sns.violinplot(x='DeviceType',y='TimeSpentOnCourse',data=df,hue='CourseCompletion',color='pink')
# Out:
# <ipython-input-23-4388c758116d>:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:pink'` for the same effect.
#
#   sns.violinplot(x='DeviceType',y='TimeSpentOnCourse',data=df,hue='CourseCompletion',color='pink')
# <Axes: xlabel='DeviceType', ylabel='TimeSpentOnCourse'>

# %%
# Create a scatter plot
plt.figure(figsize=(10, 5))
sns.scatterplot(x='CompletionRate', y='QuizScores', data=df, hue='CourseCompletion', palette='coolwarm')
# Out:
# <Axes: xlabel='CompletionRate', ylabel='QuizScores'>

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['CourseCategory'] = le.fit_transform(df['CourseCategory'])

# %%
df.head()
# Out:
#    UserID  CourseCategory  TimeSpentOnCourse  NumberOfVideosWatched  \
# 0    5618               2          29.979719                     17
# 1    4326               0          27.802640                      1
# 2    5849               0          86.820485                     14
# 3    4992               4          35.038427                     17
# 4    3866               3          92.490647                     16
#
#    NumberOfQuizzesTaken  QuizScores  CompletionRate  DeviceType  \
# 0                     3   50.365656       20.860773           1
# 1                     5   62.615970       65.632415           1
# 2                     2   78.458962       63.812007           1
# 3                    10   59.198853       95.433162           0
# 4                     0   98.428285       18.102478           0
#
#    CourseCompletion
# 0                 0
# 1                 0
# 2                 1
# 3                 1
# 4                 0

# %%
df = df.drop(['UserID'],axis=1)

# %%
X = df.iloc[:,0:7]
X.head()
# Out:
#    CourseCategory  TimeSpentOnCourse  NumberOfVideosWatched  \
# 0               2          29.979719                     17
# 1               0          27.802640                      1
# 2               0          86.820485                     14
# 3               4          35.038427                     17
# 4               3          92.490647                     16
#
#    NumberOfQuizzesTaken  QuizScores  CompletionRate  DeviceType
# 0                     3   50.365656       20.860773           1
# 1                     5   62.615970       65.632415           1
# 2                     2   78.458962       63.812007           1
# 3                    10   59.198853       95.433162           0
# 4                     0   98.428285       18.102478           0

# %%
from sklearn.preprocessing import MinMaxScaler
scalar=MinMaxScaler()
X_scaled=scalar.fit_transform(X)

# %%
X_scaled[0:5]
# Out:
# array([[0.5       , 0.29270908, 0.85      , 0.3       , 0.00721221,
#         0.20857623, 1.        ],
#        [0.        , 0.27071556, 0.05      , 0.5       , 0.25226816,
#         0.65642529, 1.        ],
#        [0.        , 0.86693172, 0.7       , 0.2       , 0.56919224,
#         0.63821581, 1.        ],
#        [1.        , 0.34381367, 0.85      , 1.        , 0.18391196,
#         0.95452104, 0.        ],
#        [0.75      , 0.92421342, 0.8       , 0.        , 0.96865966,
#         0.18098511, 0.        ]])

# %%
y = df.iloc[:,-1]
y.head()
# Out:
# 0    0
# 1    0
# 2    1
# 3    1
# 4    0
# Name: CourseCompletion, dtype: int64

# %%
#from sklearn.preprocessing import StandardScaler
#scaler = StandardScaler()

#X_scaled = scaler.fit_transform(X)

# %%
X_scaled.shape
# Out:
# (9000, 7)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X_scaled,y,test_size=0.2,random_state=2)

# %%
X_train.shape
# Out:
# (7200, 7)

# %%
import tensorflow as tf
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense

# %%
model = Sequential()

model.add(Dense(7,activation='relu',input_dim=7))
model.add(Dense(10,activation='relu'))
model.add(Dense(10,activation='relu'))
model.add(Dense(10,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 7)                 56
#
#  dense_1 (Dense)             (None, 10)                80
#
#  dense_2 (Dense)             (None, 10)                110
#
#  dense_3 (Dense)             (None, 10)                110
#
#  dense_4 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 367 (1.43 KB)
# Trainable params: 367 (1.43 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy',metrics=['accuracy'])
history = model.fit(X_scaled,y,epochs=100,batch_size=1,validation_split=0.2)
# Out:
# Epoch 1/100
# 7200/7200 [==============================] - 21s 3ms/step - loss: 0.4217 - accuracy: 0.8308 - val_loss: 0.4352 - val_accuracy: 0.8300
# Epoch 2/100
# 7200/7200 [==============================] - 21s 3ms/step - loss: 0.4471 - accuracy: 0.8281 - val_loss: 0.5973 - val_accuracy: 0.7456
# Epoch 3/100
# 7200/7200 [==============================] - 20s 3ms/step - loss: 0.4680 - accuracy: 0.8297 - val_loss: 0.4212 - val_accuracy: 0.8122
# Epoch 4/100
# 7200/7200 [==============================] - 22s 3ms/step - loss: 0.4697 - accuracy: 0.8231 - val_loss: 0.4281 - val_accuracy: 0.8294
# Epoch 5/100
# 7200/7200 [==============================] - 19s 3ms/step - loss: 0.4638 - accuracy: 0.8243 - val_loss: 0.4683 - val_accuracy: 0.8167
# Epoch 6/100
# 7200/7200 [==============================] - 20s 3ms/step - loss: 0.4826 - accuracy: 0.8271 - val_loss: 0.4301 - val_accuracy: 0.8272
# Epoch 7/100
# 7200/7200 [==============================] - 19s 3ms/step - loss: 0.4897 - accuracy: 0.8232 - val_loss: 0.4358 - val_accuracy: 0.8300
# Epoch 8/100
# 7200/7200 [==============================] - 21s 3ms/step - loss: 0.4935 - accuracy: 0.8251 - val_loss: 0.5290 - val_accuracy: 0.8011
# Epoch 9/100
# 7200/7200 [==============================] - 19s 3ms/step - loss: 0.5084 - accuracy: 0.8242 - val_loss: 0.5473 - val_accuracy: 0.8117
# Epoch 10/100
# 7200/7200 [==============================] - 22s 3ms/step - loss: 0.5169 - accuracy: 0.8183 - val_loss: 0.5516 - val_accuracy: 0.8167
# Epoch 11/100
# 7200/7200 [==============================] - 19s 3ms/step - loss: 0.5277 - accuracy: 0.8163 - val_loss: 0.4630 - val_accuracy: 0.8228
# Epoch 12/100
# 7200/7200 [==============================] - 22s 3ms/step - loss: 0.5240 - accuracy: 0.8161 - val_loss: 0.4739 - val_accuracy: 0.8183
# Epoch 13/100
# 7200/7200 [==============================] - 19s 3ms/step - loss: 0.5108 - accuracy: 0.8160 - val_loss: 0.5562 - val_accuracy: 0.8161
# Epoch 14/100
# 7200/7200 [==============================] - 23s 3ms/step - loss: 0.4952 - accuracy: 0.8226 - val_loss: 0.4844 - val_accuracy: 0.8150
# Epoch 15/100
# 7200/7200 [==============================] - 19s 3ms/step - loss: 0.4828 - accuracy: 0.8208 - val_loss: 0.4692 - val_accuracy: 0.8294
# Epoch 16/100
# 7200/7200 [==============================] - 23s 3ms/step - loss: 0.4914 - accuracy: 0.8204 - val_loss: 0.4228 - val_accuracy: 0.8283
# Epoch 17/100
# 7200/7200 [==============================] - 19s 3ms/step - loss: 0.4828 - accuracy: 0.8257 - val_loss: 0.4493 - val_accuracy: 0.8111
# Epoch 18/100
# 7200/7200 [==============================] - 22s 3ms/step - loss: 0.5008 - accuracy: 0.8211 - val_loss: 0.4773 - val_accuracy: 0.8094
# Epoch 19/100
# 7200/7200 [==============================] - 19s 3ms/step - loss: 0.5130 - accuracy: 0.8239 - val_loss: 0.4977 - val_accuracy: 0.8267
# Epoch 20/100
# 7200/7200 [==============================] - 22s 3ms/step - loss: 0.5240 - accuracy: 0.8214 - val_loss: 0.4523 - val_accuracy: 0.8244
# Epoch 21/100
# 7200/7200 [==============================] - 19s 3ms/step - loss: 0.5228 - accuracy: 0.8197 - val_loss: 0.5361 - val_accuracy: 0.8250
# Epoch 22/100
# 7200/7200 [==============================] - 20s 3ms/step - loss: 0.5531 - accuracy: 0.8125 - val_loss: 0.4838 - val_accuracy: 0.8306
# Epoch 23/100
# 7200/7200 [==============================] - 18s 3ms/step - loss: 0.5292 - accuracy: 0.8207 - val_loss: 0.7342 - val_accuracy: 0.7928
# Epoch 24/100
# 7200/7200 [==============================] - 21s 3ms/step - loss: 0.5461 - accuracy: 0.8175 - val_loss: 0.4691 - val_accuracy: 0.8094
# Epoch 25/100
# 7200/7200 [==============================] - 20s 3ms/step - loss: 0.5327 - accuracy: 0.8186 - val_loss: 0.5014 - val_accuracy: 0.8139
# Epoch 26/100
# 7200/7200 [==============================] - 19s 3ms/step - loss: 0.5306 - accuracy: 0.8194 - val_loss: 0.5640 - val_accuracy: 0.8250
# Epoch 27/100
# 7200/7200 [==============================] - 21s 3ms/step - loss: 0.5232 - accuracy: 0.8211 - val_loss: 0.4955 - val_accuracy: 0.8211
# Epoch 28/100
# 7200/7200 [==============================] - 20s 3ms/step - loss: 0.5270 - accuracy: 0.8232 - val_loss: 0.4926 - val_accuracy: 0.8267
# Epoch 29/100
# 7200/7200 [==============================] - 20s 3ms/step - loss: 0.5461 - accuracy: 0.8194 - val_loss: 0.6210 - val_accuracy: 0.8044
# Epoch 30/100
# 7200/7200 [==============================] - 20s 3ms/step - loss: 0.5309 - accuracy: 0.8157 - val_loss: 0.6124 - val_accuracy: 0.8200
# Epoch 31/100
# 7200/7200 [==============================] - 21s 3ms/step - loss: 0.5486 - accuracy: 0.8096 - val_loss: 0.5646 - val_accuracy: 0.8117
# Epoch 32/100
# 7200/7200 [==============================] - 20s 3ms/step - loss: 0.5503 - accuracy: 0.8140 - val_loss: 0.5534 - val_accuracy: 0.8133
# Epoch 33/100
# 7200/7200 [==============================] - 21s 3ms/step - loss: 0.5428 - accuracy: 0.8049 - val_loss: 0.7113 - val_accuracy: 0.8006
# Epoch 34/100
# 7200/7200 [==============================] - 20s 3ms/step - loss: 0.5391 - accuracy: 0.8110 - val_loss: 0.5621 - val_accuracy: 0.8261
# Epoch 35/100
# 7200/7200 [==============================] - 22s 3ms/step - loss: 0.5346 - accuracy: 0.8168 - val_loss: 0.4695 - val_accuracy: 0.8139
# Epoch 36/100
# 7200/7200 [==============================] - 20s 3ms/step - loss: 0.5272 - accuracy: 0.8172 - val_loss: 0.4893 - val_accuracy: 0.8006
# Epoch 37/100
# 7200/7200 [==============================] - 22s 3ms/step - loss: 0.5215 - accuracy: 0.8201 - val_loss: 0.4485 - val_accuracy: 0.8067
# Epoch 38/100
# 7200/7200 [==============================] - 19s 3ms/step - loss: 0.5070 - accuracy: 0.8221 - val_loss: 0.5680 - val_accuracy: 0.8133
# Epoch 39/100
# 7200/7200 [==============================] - 18s 2ms/step - loss: 0.5111 - accuracy: 0.8289 - val_loss: 0.4755 - val_accuracy: 0.8139
# Epoch 40/100
# 7200/7200 [==============================] - 22s 3ms/step - loss: 0.5042 - accuracy: 0.8288 - val_loss: 0.4966 - val_accuracy: 0.8250
# Epoch 41/100
# 7200/7200 [==============================] - 18s 3ms/step - loss: 0.5033 - accuracy: 0.8257 - val_loss: 0.4977 - val_accuracy: 0.8078
# Epoch 42/100
# 7200/7200 [==============================] - 20s 3ms/step - loss: 0.5143 - accuracy: 0.8306 - val_loss: 0.5113 - val_accuracy: 0.8283
# Epoch 43/100
# 7200/7200 [==============================] - 18s 3ms/step - loss: 0.5366 - accuracy: 0.8274 - val_loss: 0.6267 - val_accuracy: 0.8356
# Epoch 44/100
# 7200/7200 [==============================] - 21s 3ms/step - loss: 0.5274 - accuracy: 0.8353 - val_loss: 0.5290 - val_accuracy: 0.8344
# Epoch 45/100
# 7200/7200 [==============================] - 20s 3ms/step - loss: 0.5322 - accuracy: 0.8307 - val_loss: 0.4619 - val_accuracy: 0.8306
# Epoch 46/100
# 7200/7200 [==============================] - 23s 3ms/step - loss: 0.5228 - accuracy: 0.8343 - val_loss: 0.4549 - val_accuracy: 0.8389
# Epoch 47/100
# 7200/7200 [==============================] - 25s 3ms/step - loss: 0.5286 - accuracy: 0.8307 - val_loss: 0.4810 - val_accuracy: 0.8333
# Epoch 48/100
# 7200/7200 [==============================] - 22s 3ms/step - loss: 0.5309 - accuracy: 0.8272 - val_loss: 0.5879 - val_accuracy: 0.8178
# Epoch 49/100
# 7200/7200 [==============================] - 22s 3ms/step - loss: 0.5180 - accuracy: 0.8281 - val_loss: 0.5106 - val_accuracy: 0.8272
# Epoch 50/100
# 7200/7200 [==============================] - 20s 3ms/step - loss: 0.5231 - accuracy: 0.8283 - val_loss: 0.5557 - val_accuracy: 0.8311
# Epoch 51/100
# 7200/7200 [==============================] - 23s 3ms/step - loss: 0.5222 - accuracy: 0.8276 - val_loss: 0.5854 - val_accuracy: 0.8139
# Epoch 52/100
# 7200/7200 [==============================] - 19s 3ms/step - loss: 0.5221 - accuracy: 0.8283 - val_loss: 0.5165 - val_accuracy: 0.8283
# Epoch 53/100
# 7200/7200 [==============================] - 21s 3ms/step - loss: 0.5190 - accuracy: 0.8203 - val_loss: 0.5668 - val_accuracy: 0.8189
# Epoch 54/100
# 7200/7200 [==============================] - 19s 3ms/step - loss: 0.5127 - accuracy: 0.8265 - val_loss: 0.5087 - val_accuracy: 0.8278
# Epoch 55/100
# 7200/7200 [==============================] - 19s 3ms/step - loss: 0.5325 - accuracy: 0.8261 - val_loss: 0.4779 - val_accuracy: 0.8344
# Epoch 56/100
# 7200/7200 [==============================] - 18s 3ms/step - loss: 0.5104 - accuracy: 0.8289 - val_loss: 0.5310 - val_accuracy: 0.8211
# Epoch 57/100
# 7200/7200 [==============================] - 19s 3ms/step - loss: 0.5121 - accuracy: 0.8278 - val_loss: 0.5217 - val_accuracy: 0.8111
# Epoch 58/100
# 7200/7200 [==============================] - 19s 3ms/step - loss: 0.5015 - accuracy: 0.8292 - val_loss: 0.4447 - val_accuracy: 0.8222
# Epoch 59/100
# 7200/7200 [==============================] - 18s 3ms/step - loss: 0.4999 - accuracy: 0.8342 - val_loss: 0.4491 - val_accuracy: 0.8311
# Epoch 60/100
# 7200/7200 [==============================] - 21s 3ms/step - loss: 0.4956 - accuracy: 0.8279 - val_loss: 0.5264 - val_accuracy: 0.8183
# Epoch 61/100
# 7200/7200 [==============================] - 18s 3ms/step - loss: 0.5070 - accuracy: 0.8215 - val_loss: 0.5045 - val_accuracy: 0.8228
# Epoch 62/100
# 7200/7200 [==============================] - 21s 3ms/step - loss: 0.5071 - accuracy: 0.8226 - val_loss: 0.6146 - val_accuracy: 0.8150
# Epoch 63/100
# 7200/7200 [==============================] - 19s 3ms/step - loss: 0.5201 - accuracy: 0.8233 - val_loss: 0.5447 - val_accuracy: 0.8239
# Epoch 64/100
# 7200/7200 [==============================] - 19s 3ms/step - loss: 0.5497 - accuracy: 0.8231 - val_loss: 0.5376 - val_accuracy: 0.8389
# Epoch 65/100
# 7200/7200 [==============================] - 22s 3ms/step - loss: 0.5546 - accuracy: 0.8239 - val_loss: 0.5752 - val_accuracy: 0.7478
# Epoch 66/100
# 7200/7200 [==============================] - 18s 3ms/step - loss: 0.5529 - accuracy: 0.8242 - val_loss: 0.5039 - val_accuracy: 0.8322
# Epoch 67/100
# 7200/7200 [==============================] - 19s 3ms/step - loss: 0.5603 - accuracy: 0.8193 - val_loss: 0.5237 - val_accuracy: 0.8211
# Epoch 68/100
# 7200/7200 [==============================] - 17s 2ms/step - loss: 0.5642 - accuracy: 0.8182 - val_loss: 0.5799 - val_accuracy: 0.7906
# Epoch 69/100
# 7200/7200 [==============================] - 18s 2ms/step - loss: 0.5498 - accuracy: 0.8196 - val_loss: 0.5579 - val_accuracy: 0.8239
# Epoch 70/100
# 7200/7200 [==============================] - 18s 3ms/step - loss: 0.5747 - accuracy: 0.8158 - val_loss: 0.6612 - val_accuracy: 0.8378
# Epoch 71/100
# 7200/7200 [==============================] - 18s 3ms/step - loss: 0.5601 - accuracy: 0.8104 - val_loss: 0.5671 - val_accuracy: 0.8156
# Epoch 72/100
# 7200/7200 [==============================] - 22s 3ms/step - loss: 0.5568 - accuracy: 0.8085 - val_loss: 0.5871 - val_accuracy: 0.8000
# Epoch 73/100
# 7200/7200 [==============================] - 18s 2ms/step - loss: 0.5575 - accuracy: 0.8121 - val_loss: 0.7383 - val_accuracy: 0.8211
# Epoch 74/100
# 7200/7200 [==============================] - 18s 3ms/step - loss: 0.5589 - accuracy: 0.8039 - val_loss: 0.6093 - val_accuracy: 0.8194
# Epoch 75/100
# 7200/7200 [==============================] - 20s 3ms/step - loss: 0.5532 - accuracy: 0.8217 - val_loss: 0.6464 - val_accuracy: 0.8344
# Epoch 76/100
# 7200/7200 [==============================] - 18s 2ms/step - loss: 0.5489 - accuracy: 0.8225 - val_loss: 0.5790 - val_accuracy: 0.8211
# Epoch 77/100
# 7200/7200 [==============================] - 18s 3ms/step - loss: 0.5325 - accuracy: 0.8203 - val_loss: 0.5870 - val_accuracy: 0.8322
# Epoch 78/100
# 7200/7200 [==============================] - 18s 2ms/step - loss: 0.5364 - accuracy: 0.8206 - val_loss: 0.5618 - val_accuracy: 0.8322
# Epoch 79/100
# 7200/7200 [==============================] - 18s 2ms/step - loss: 0.5385 - accuracy: 0.8242 - val_loss: 0.4895 - val_accuracy: 0.7750
# Epoch 80/100
# 7200/7200 [==============================] - 18s 2ms/step - loss: 0.5239 - accuracy: 0.8201 - val_loss: 0.4841 - val_accuracy: 0.8228
# Epoch 81/100
# 7200/7200 [==============================] - 20s 3ms/step - loss: 0.5212 - accuracy: 0.8271 - val_loss: 0.5274 - val_accuracy: 0.8206
# Epoch 82/100
# 7200/7200 [==============================] - 19s 3ms/step - loss: 0.5295 - accuracy: 0.8279 - val_loss: 0.5128 - val_accuracy: 0.8300
# Epoch 83/100
# 7200/7200 [==============================] - 20s 3ms/step - loss: 0.5303 - accuracy: 0.8296 - val_loss: 0.7167 - val_accuracy: 0.8344
# Epoch 84/100
# 7200/7200 [==============================] - 19s 3ms/step - loss: 0.5390 - accuracy: 0.8263 - val_loss: 0.6067 - val_accuracy: 0.7861
# Epoch 85/100
# 7200/7200 [==============================] - 22s 3ms/step - loss: 0.5547 - accuracy: 0.8185 - val_loss: 0.5831 - val_accuracy: 0.7700
# Epoch 86/100
# 7200/7200 [==============================] - 19s 3ms/step - loss: 0.5291 - accuracy: 0.8226 - val_loss: 0.6443 - val_accuracy: 0.8372
# Epoch 87/100
# 7200/7200 [==============================] - 19s 3ms/step - loss: 0.5417 - accuracy: 0.8215 - val_loss: 0.5167 - val_accuracy: 0.7722
# Epoch 88/100
# 7200/7200 [==============================] - 20s 3ms/step - loss: 0.5584 - accuracy: 0.8161 - val_loss: 0.5019 - val_accuracy: 0.8250
# Epoch 89/100
# 7200/7200 [==============================] - 19s 3ms/step - loss: 0.5487 - accuracy: 0.8200 - val_loss: 0.5699 - val_accuracy: 0.8150
# Epoch 90/100
# 7200/7200 [==============================] - 19s 3ms/step - loss: 0.5511 - accuracy: 0.8129 - val_loss: 0.5002 - val_accuracy: 0.8256
# Epoch 91/100
# 7200/7200 [==============================] - 19s 3ms/step - loss: 0.5322 - accuracy: 0.8244 - val_loss: 0.4935 - val_accuracy: 0.8239
# Epoch 92/100
# 7200/7200 [==============================] - 21s 3ms/step - loss: 0.5287 - accuracy: 0.8263 - val_loss: 0.5037 - val_accuracy: 0.8222
# Epoch 93/100
# 7200/7200 [==============================] - 20s 3ms/step - loss: 0.5293 - accuracy: 0.8269 - val_loss: 0.5119 - val_accuracy: 0.8278
# Epoch 94/100
# 7200/7200 [==============================] - 22s 3ms/step - loss: 0.5331 - accuracy: 0.8297 - val_loss: 0.5079 - val_accuracy: 0.8117
# Epoch 95/100
# 7200/7200 [==============================] - 22s 3ms/step - loss: 0.5363 - accuracy: 0.8225 - val_loss: 0.4739 - val_accuracy: 0.7972
# Epoch 96/100
# 7200/7200 [==============================] - 20s 3ms/step - loss: 0.5458 - accuracy: 0.8239 - val_loss: 0.5171 - val_accuracy: 0.8300
# Epoch 97/100
# 7200/7200 [==============================] - 18s 3ms/step - loss: 0.5217 - accuracy: 0.8279 - val_loss: 0.4967 - val_accuracy: 0.8356
# Epoch 98/100
# 7200/7200 [==============================] - 21s 3ms/step - loss: 0.5162 - accuracy: 0.8281 - val_loss: 0.5079 - val_accuracy: 0.8200
# Epoch 99/100
# 7200/7200 [==============================] - 18s 3ms/step - loss: 0.5185 - accuracy: 0.8242 - val_loss: 0.5112 - val_accuracy: 0.8361
# Epoch 100/100
# 7200/7200 [==============================] - 19s 3ms/step - loss: 0.5325 - accuracy: 0.8300 - val_loss: 0.5243 - val_accuracy: 0.8189

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
